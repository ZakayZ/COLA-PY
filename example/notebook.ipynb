# %%
import colapy

# %% [markdown]
# ## Plain Python module

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('.').resolve()))

CONFIG = """<?xml version="1.0" encoding="UTF-8"?>
<program>
    <generator name="PythonGenerator" class="pylib.Generator"/>
    <converter name="PythonConverter" class="pylib.Converter"/>
    <writer name="PythonWriter" class="pylib.Writer"/>
</program>
"""

print('Initializing Run Manager...')
rm = colapy.RunManager().load_module('COLA-Py').load_config(config=CONFIG)
print('Running...')
rm.run()
# Out:
# Initializing Run Manager...
# Parsing XML file:
# filter name: PythonGenerator
# params:
# class: pylib.Generator
# init: <pylib.Generator object at 0x10cadd9d0>, {'class': 'pylib.Generator'}
# init: <pylib.Converter object at 0x10cadd310>, {'class': 'pylib.Converter'}
# init: <pylib.Writer object at 0x10caf9040>, {'class': 'pylib.Writer'}
# Running...
# {'initial_state': {'b': 0.0,
#                    'energy': 0.0,
#                    'initial_particles': [],
#                    'n_coll': 0,
#                    'n_coll_nn': 0,
#                    'n_coll_pn': 0,
#                    'n_coll_pp': 0,
#                    'n_part': 0,
#                    'n_part_a': 0,
#                    'n_part_b': 0,
#                    'pdg_code_a': 11,
#                    'pdg_code_b': 13,
#                    'phi_rot_a': 0.0,
#                    'phi_rot_b': 0.0,
#                    'pz_a': 0.0,
#                    'pz_b': 0.0,
#                    'sect_nn': 0.0,
#                    'theta_rot_a': 0.0,
#                    'theta_rot_b': 0.0},
#  'particles': []}
# filter name: PythonConverter
# params:
# class: pylib.Converter
# filter name: PythonWriter
# params:
# class: pylib.Writer

# %% [markdown]
# ## Plain C++ module run from Python

# %%
CONFIG = """<?xml version="1.0" encoding="UTF-8"?>
<program>
    <generator name="ExGenerator"/>
    <converter name="ExConverter"/>
    <writer name="ExWriter"/>
</program>
"""

print('Initializing Run Manager...')
rm = colapy.RunManager().load_module('ExModule').load_config(config=CONFIG)
print('Running...')
rm.run()
# Out:
# Initializing Run Manager...
# Running...
# Parsing XML file:
# filter name: ExGenerator
# params:
# filter name: ExConverter
# params:
# filter name: ExWriter
# params:
# 0, 0, 0
# 0, 0, 0

# %% [markdown]
# ## Combine Python and C++ modules

# %%
import pylib
import json


class JSONWriter(colapy.WriterBase):
    file: str

    def __init__(self, **kwargs: dict[str, str]) -> None:
        self.file = kwargs.get('file', 'out.jsonl')
        with open(self.file, 'w') as f:
            pass

    def __call__(self, event_data: colapy.EventData) -> None:
        with open(self.file, 'a') as f:
            json.dump(pylib.to_dict(event_data), f)


CONFIG = """<?xml version="1.0" encoding="UTF-8"?>
<program>
    <generator name="URQMDGenerator"/>
    <writer name="PythonWriter" class="JSONWriter" file="config_out.jsonl"/>
</program>
"""

print('Initializing Run Manager...')
rm = (
    colapy.RunManager()
    .load_module('COLA-Py')
    .load_module('Urqmd4')
    .load_config(config=CONFIG)
)
print('Running...')
rm.run()
# Out:
# Initializing Run Manager...
# Parsing XML file:
# filter name: URQMDGenerator
# params:
#  #############################################################
#  ##                                                         ##
#  ## UrQMD 4.0        University of Frankfurt                ##
#  ##                  http://urqmd.org                       ##
#  ##                  bleicher@itp.uni-frankfurt.de          ##
#  #############################################################
#  ##                                                         ##
#  ##     Please cite when using this model:                  ##
#  ##     S.A.Bass et al., Prog.Part.Nucl.Phys. 41 (1998) 225 ##
#  ##     M.Bleicher et al., J.Phys. G25  (1999) 1859         ##
#  ##                                                         ##
#  #############################################################
#  ##     UrQMD uses Pythia6.409 by T. Sjorstrand             ##
#  #############################################################
#  ##                                                         ##
#  ##     If hydrodynamic evolution is switched on (CTO 45 1) ##
#  ##     UrQMD uses the SHASTA algorithm by D. Rischke       ##
#  ##     Please cite when using the hybrid code:             ##
#  ##     D. Rischke et al., Nucl.Phys. A 595 (1995) 346      ##
#  ##     D. Rischke et al., Nucl.Phys. A 595 (1995) 383      ##
#  ##     H. Petersen et al., Phys.Rev. C78 (2008) 044901     ##
#  ##                                                         ##
#  #############################################################
#  Looking for the tabulated decay width...
#  O.K.
#  reading...
#  version=           9
#  O.K.
#  tabver=           9   O.K.
#  widnsp=         120   O.K.
# filter name: PythonWriter
# params:
# file: config_out.jsonl
# class: JSONWriter
# Running...

# %% [markdown]
# ## Консольная утилита

# %%
# !export PYTHONPATH="$PYTHONPATH:$(pwd)" && cola run --config="config.xml" --library="COLA-Py"
# Out:
# Parsing XML file:
# filter name: PythonGenerator
# params:
# class: pylib.Generator
# init: <pylib.Generator object at 0x101c79730>, {'class': 'pylib.Generator'}
# filter name: PythonConverter
# params:
# class: pylib.Converter
# init: <pylib.Converter object at 0x101c79820>, {'class': 'pylib.Converter'}
# filter name: PythonWriter
# params:
# class: pylib.Writer
# init: <pylib.Writer object at 0x101c79640>, {'class': 'pylib.Writer'}
# {'initial_state': {'b': 0.0,
#                    'energy': 0.0,
#                    'initial_particles': [],
#                    'n_coll': 0,
#                    'n_coll_nn': 0,
#                    'n_coll_pn': 0,
#                    'n_coll_pp': 0,
#                    'n_part': 0,
#                    'n_part_a': 0,
#                    'n_part_b': 0,
#                    'pdg_code_a': 11,
#                    'pdg_code_b': 13,
#                    'phi_rot_a': 0.0,
#                    'phi_rot_b': 0.0,
#                    'pz_a': 0.0,
#                    'pz_b': 0.0,
#                    'sect_nn': 0.0,
#                    'theta_rot_a': 0.0,
#                    'theta_rot_b': 0.0},
#  'particles': []}

# %%
import pylib
import json


class JSONWriter(colapy.WriterBase):
    file: str

    def __init__(self, **kwargs: dict[str, str]) -> None:
        self.file = kwargs.get('file', 'out.jsonl')
        with open(self.file, 'w') as f:
            pass

    def __call__(self, event_data: colapy.EventData) -> None:
        with open(self.file, 'a') as f:
            json.dump(pylib.to_dict(event_data), f)


CONFIG = """<?xml version="1.0" encoding="UTF-8"?>
<program>
    <generator name="ExGenerator"/>
    <converter name="ExConverter"/>
    <writer name="PythonWriter" class="JSONWriter" file="config_out.jsonl"/>
</program>
"""

print('Initializing Run Manager...')
rm = (
    colapy.RunManager()
    .load_module('COLA-Py')
    .load_module('Deexcitation')
    .load_module('ExModule')
    .load_config(config=CONFIG)
)
print('Running...')
rm.run()
# Out:
# Initializing Run Manager...
# Parsing XML file:
# filter name: ExGenerator
# params:
# filter name: ExConverter
# params:
# filter name: PythonWriter
# params:
# class: JSONWriter
# file: config_out.jsonl
# Running...
