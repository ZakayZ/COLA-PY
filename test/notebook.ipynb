# %%
import colapy

# %% [markdown]
# ## Plain Python module

# %%
import tempfile


CONFIG = '''
<?xml version="1.0" encoding="UTF-8" ?>
<program>
    <generator name="PythonGenerator" class="pylib.Generator"/>
    <converter name="PythonConverter" class="pylib.Converter"/>
    <writer name="PythonWriter" class="pylib.Writer"/>
</program>
'''

with tempfile.NamedTemporaryFile(mode='w', suffix='.xml', delete_on_close=False) as tmp:
    tmp.name
    tmp.write(CONFIG)
    tmp.close()

    print('Initializing Run Manager...')
    rm = colapy.RunManager().load_library('COLA-Py').load_config(tmp.name)
    print('Running...')
    rm.run()
# Out:
# Initializing Run Manager...
# Parsing XML file:
# filter name: PythonGenerator
# params:
# class: pylib.Generator
# init: <pylib.Generator object at 0x1068cc5f0>, {'class': 'pylib.Generator'}
# init: <pylib.Converter object at 0x1068cc380>, {'class': 'pylib.Converter'}
# init: <pylib.Writer object at 0x1068cc2c0>, {'class': 'pylib.Writer'}
# Running...
# {'initial_state': {'b': 0.0,
#                    'energy': 0.0,
#                    'initial_particles': [],
#                    'n_coll': 0,
#                    'n_coll_nn': 0,
#                    'n_coll_pn': 0,
#                    'n_coll_pp': 0,
#                    'n_part': 0,
#                    'n_part_a': 0,
#                    'n_part_b': 0,
#                    'pdg_code_a': 11,
#                    'pdg_code_b': 13,
#                    'phi_rot_a': 0.0,
#                    'phi_rot_b': 0.0,
#                    'pz_a': 0.0,
#                    'pz_b': 0.0,
#                    'sect_nn': 0.0,
#                    'theta_rot_a': 0.0,
#                    'theta_rot_b': 0.0},
#  'particles': []}
# filter name: PythonConverter
# params:
# class: pylib.Converter
# filter name: PythonWriter
# params:
# class: pylib.Writer

# %% [markdown]
# ## Plain C++ module run from Python

# %%
import tempfile


CONFIG = '''
<?xml version="1.0" encoding="UTF-8" ?>
<program>
    <generator name="ExGenerator"/>
    <converter name="ExConverter"/>
    <writer name="ExWriter"/>
</program>
'''

with tempfile.NamedTemporaryFile(mode='w', suffix='.xml', delete_on_close=False) as tmp:
    tmp.name
    tmp.write(CONFIG)
    tmp.close()

    print('Initializing Run Manager...')
    rm = colapy.RunManager().load_library('ExModule').load_config(tmp.name)
    print('Running...')
    rm.run()
# Out:
# Initializing Run Manager...
# Running...
# Parsing XML file:
# filter name: ExGenerator
# params:
# filter name: ExConverter
# params:
# filter name: ExWriter
# params:
# 0, 0, 0
# 0, 0, 0

# %% [markdown]
# ## Combine Python and C++ modules

# %%
import pylib
import json


class JSONWriter(colapy.WriterBase):
    file: str

    def __init__(self, **kwargs: dict[str, str]) -> None:
        self.file = kwargs.get('file', 'out.jsonl')
        with open(self.file, 'w') as f:
            pass

    def __call__(self, event_data: colapy.EventData) -> None:
        with open(self.file, 'a') as f:
            json.dump(pylib.to_dict(event_data), f)


import tempfile


CONFIG = '''
<?xml version="1.0" encoding="UTF-8" ?>
<program>
    <generator name="ExGenerator"/>
    <converter name="ExConverter"/>
    <writer name="PythonWriter" class="JSONWriter" file="config_out.jsonl"/>
</program>
'''

with tempfile.NamedTemporaryFile(mode='w', suffix='.xml', delete_on_close=False) as tmp:
    tmp.name
    tmp.write(CONFIG)
    tmp.close()

    print('Initializing Run Manager...')
    rm = colapy.RunManager().load_library('COLA-Py').load_library('ExModule').load_config(tmp.name)
    print('Running...')
    rm.run()
# Out:
# Initializing Run Manager...
# Parsing XML file:
# Running...
# filter name: ExGenerator
# params:
# filter name: ExConverter
# params:
# filter name: PythonWriter
# params:
# class: JSONWriter
# file: config_out.jsonl

# %% [markdown]
# ## Консольная утилита

# %%
# !export PYTHONPATH="$PYTHONPATH:$(pwd)" && cola run --config="data/config.xml" --library="COLA-Py"
# Out:
# Parsing XML file:
# filter name: PythonGenerator
# params:
# class: pylib.Generator
# init: <pylib.Generator object at 0x1038fd070>, {'class': 'pylib.Generator'}
# filter name: PythonConverter
# params:
# class: pylib.Converter
# init: <pylib.Converter object at 0x1038fd160>, {'class': 'pylib.Converter'}
# filter name: PythonWriter
# params:
# class: pylib.Writer
# init: <pylib.Writer object at 0x1038fd010>, {'class': 'pylib.Writer'}
# {'initial_state': {'b': 0.0,
#                    'energy': 0.0,
#                    'initial_particles': [],
#                    'n_coll': 0,
#                    'n_coll_nn': 0,
#                    'n_coll_pn': 0,
#                    'n_coll_pp': 0,
#                    'n_part': 0,
#                    'n_part_a': 0,
#                    'n_part_b': 0,
#                    'pdg_code_a': 11,
#                    'pdg_code_b': 13,
#                    'phi_rot_a': 0.0,
#                    'phi_rot_b': 0.0,
#                    'pz_a': 0.0,
#                    'pz_b': 0.0,
#                    'sect_nn': 0.0,
#                    'theta_rot_a': 0.0,
#                    'theta_rot_b': 0.0},
#  'particles': []}

# %%
import pylib
import json


class JSONWriter(colapy.WriterBase):
    file: str

    def __init__(self, **kwargs: dict[str, str]) -> None:
        self.file = kwargs.get('file', 'out.jsonl')
        with open(self.file, 'w') as f:
            pass

    def __call__(self, event_data: colapy.EventData) -> None:
        with open(self.file, 'a') as f:
            json.dump(pylib.to_dict(event_data), f)


import tempfile


CONFIG = '''
<?xml version="1.0" encoding="UTF-8" ?>
<program>
    <generator name="ExGenerator"/>
    <converter name="ExConverter"/>
    <writer name="PythonWriter" class="JSONWriter" file="config_out.jsonl"/>
</program>
'''

with tempfile.NamedTemporaryFile(mode='w', suffix='.xml', delete_on_close=False) as tmp:
    tmp.name
    tmp.write(CONFIG)
    tmp.close()

    print('Initializing Run Manager...')
    rm = colapy.RunManager().load_library('COLA-Py').load_library('Deexcitation').load_library('ExModule').load_config(tmp.name)
    print('Running...')
    rm.run()
# Out:
# Initializing Run Manager...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 36
#      33 tmp.close()
#      35 print('Initializing Run Manager...')
# ---> 36 rm = colapy.RunManager().load_library('COLA-Py').load_library('Deexcitation').load_library('ExModule').load_config(tmp.name)
#      37 print('Running...')
#      38 rm.run()
#
# RuntimeError: Failed to load library: /Users/artyasen/.local/lib/Deexcitation/libDeexcitation.dylib
# dlopen(/Users/artyasen/.local/lib/Deexcitation/libDeexcitation.dylib, 0x0001): Library not loaded: @rpath/libG4Tree.dylib
#   Referenced from: <04E06504-009E-3727-A912-8D41C3A1A9FC> /Users/artyasen/.local/lib/Deexcitation/libDeexcitation.dylib
#   Reason: tried: '/Users/artyasen/.pyenv/versions/3.12.4/lib/libG4Tree.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/artyasen/.pyenv/versions/3.12.4/lib/libG4Tree.dylib' (no such file), '/opt/homebrew/lib/libG4Tree.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libG4Tree.dylib' (no such file), '/Users/artyasen/.pyenv/versions/3.12.4/lib/libG4Tree.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/artyasen/.pyenv/versions/3.12.4/lib/libG4Tree.dylib' (no such file), '/opt/homebrew/lib/libG4Tree.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libG4Tree.dylib' (no such file), '/Users/artyasen/.pyenv/versions/3.12.4/lib/libG4Tree.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/artyasen/.pyenv/versions/3.12.4/lib/libG4Tree.dylib' (no such file), '/opt/homebrew/lib/libG4Tree.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libG4Tree.dylib' (no such file), '/usr/local/lib/libG4Tree.dylib' (no such file), '/usr/lib/libG4Tree.dylib' (no such file, not in dyld cache)
